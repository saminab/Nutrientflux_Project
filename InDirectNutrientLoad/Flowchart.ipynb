# %%
# Flowchart (rounded rectangles + diamond) — FIXED layout
# - FIGSIZE = (6.69, 5)
# - No overlapping arrows
# - Subtitle ("Adding nutrient attributes") is placed between rows (not on boxes)
# - Wrap-around arrow (3 -> 4) routed outside the container
# - Diamond -> bottom sequence routed with an elbow (no diagonal crossing)
# Exports PNG + PDF

import textwrap
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import FancyBboxPatch, FancyArrowPatch, Polygon
from matplotlib.backends.backend_pdf import PdfPages
from pathlib import Path

# ----------------------------
# Style / sizing
# ----------------------------
FIGSIZE     = (6.69, 5)
FONT        = 7.0
TITLE_FONT  = 12
SUB_FONT    = 9

BOX_FACE    = "#F2F2F2"
BOX_EDGE    = "#555555"
GROUP_FACE  = "#FBFBFB"
ARROW       = "#444444"

def wrap_label(s, width=28):
    return "\n".join(textwrap.wrap(s, width=width, break_long_words=False))

def rbox_center(ax, center, wh, text, wrap_width=28, fontsize=FONT):
    cx, cy = center
    w, h = wh
    rect = FancyBboxPatch(
        (cx - w/2, cy - h/2), w, h,
        boxstyle="round,pad=0.012,rounding_size=0.02",
        linewidth=1.0, facecolor=BOX_FACE, edgecolor=BOX_EDGE, zorder=3
    )
    ax.add_patch(rect)
    ax.text(cx, cy, wrap_label(text, wrap_width),
            ha="center", va="center", fontsize=fontsize, color="black", zorder=4)
    return {"cx": cx, "cy": cy, "w": w, "h": h}

def group_container(ax, center, wh, title):
    cx, cy = center
    w, h = wh
    cont = FancyBboxPatch(
        (cx - w/2, cy - h/2), w, h,
        boxstyle="round,pad=0.010,rounding_size=0.03",
        linewidth=1.2, facecolor=GROUP_FACE, edgecolor=BOX_EDGE, zorder=1
    )
    ax.add_patch(cont)
    ax.text(cx, cy + h/2 + 0.018, title,
            ha="center", va="bottom", fontsize=SUB_FONT, fontweight="bold",
            color="black", zorder=6)
    return cont

def diamond(ax, center, wh, text, wrap_width=30):
    cx, cy = center
    w, h = wh
    pts = np.array([
        [cx,       cy + h/2],
        [cx + w/2, cy],
        [cx,       cy - h/2],
        [cx - w/2, cy]
    ])
    poly = Polygon(pts, closed=True, facecolor=BOX_FACE,
                   edgecolor=BOX_EDGE, linewidth=1.2, zorder=3)
    ax.add_patch(poly)
    ax.text(cx, cy, wrap_label(text, wrap_width),
            ha="center", va="center", fontsize=FONT, color="black", zorder=4)
    return {"cx": cx, "cy": cy, "w": w, "h": h}

# node anchors
def right(n):  return (n["cx"] + n["w"]/2, n["cy"])
def left(n):   return (n["cx"] - n["w"]/2, n["cy"])
def top(n):    return (n["cx"], n["cy"] + n["h"]/2)
def bottom(n): return (n["cx"], n["cy"] - n["h"]/2)

def seg(ax, a, b, arrow=False, lw=1.05):
    style = "->" if arrow else "-"
    ax.add_patch(FancyArrowPatch(
        a, b,
        arrowstyle=style,
        color=ARROW,
        connectionstyle="arc3,rad=0",
        linewidth=lw,
        mutation_scale=12,
        zorder=2
    ))

def polyline(ax, pts, lw=1.05):
    # straight segments; arrow head only on last segment
    for i in range(len(pts)-1):
        seg(ax, pts[i], pts[i+1], arrow=(i == len(pts)-2), lw=lw)

# ----------------------------
# Build figure
# ----------------------------
fig = plt.figure(figsize=FIGSIZE)
ax = plt.gca()
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.axis("off")

# Title
ax.text(0.5, 0.965, "Prep input data for particle tracking",
        ha="center", va="top", fontsize=TITLE_FONT, fontweight="bold")

# Container
g_center = (0.5, 0.72)
g_size   = (0.94, 0.34)
group_container(ax, g_center, g_size, "Finding release points")

# Subtitle BETWEEN rows (won't overlap boxes)
ax.text(0.5, 0.705, "Adding nutrient attributes",
        ha="center", va="center", fontsize=SUB_FONT, fontweight="bold", zorder=6)

# Row layout
bw, bh = 0.27, 0.10
gap = 0.055
x_mid = 0.50
x1, x2, x3 = x_mid - (bw + gap), x_mid, x_mid + (bw + gap)
y1, y2 = 0.79, 0.62

# Row 1
b1 = rbox_center(ax, (x1, y1), (bw, bh), "1. Intersect stream watersheds with shoreline", wrap_width=26)
b2 = rbox_center(ax, (x2, y1), (bw, bh), "2. Snap release points to plume midpoint", wrap_width=26)
b3 = rbox_center(ax, (x3, y1), (bw, bh), "3. Create 100 particles at each location", wrap_width=26)
polyline(ax, [right(b1), left(b2)])
polyline(ax, [right(b2), left(b3)])

# Row 2
b4 = rbox_center(ax, (x1, y2), (bw, bh), "4. Add a unique ID to each particle", wrap_width=26)
b5 = rbox_center(ax, (x2, y2), (bw, bh), "5. Extract N and P for each watershed (SENSEflux)", wrap_width=26)
b6 = rbox_center(ax, (x3, y2), (bw, bh), "6. Assign N and P values to particles", wrap_width=26)
polyline(ax, [right(b4), left(b5)])
polyline(ax, [right(b5), left(b6)])

# Clean wrap-around (3 -> 4) routed OUTSIDE the container bottom
container_bottom = g_center[1] - g_size[1]/2
y_out = container_bottom - 0.02  # just below container
polyline(ax, [
    bottom(b3),
    (0.93, bottom(b3)[1]),
    (0.93, y_out),
    (x1,  y_out),
    (x1,  top(b4)[1]),
])

# Diamond
d = diamond(ax, (0.5, 0.43), (0.50, 0.12), "Compute indirect nutrient load", wrap_width=30)
polyline(ax, [bottom(b6), top(d)])

# Bottom sequence
yb = 0.23
bw2, bh2 = 0.29, 0.10
xL, xC, xR = 0.20, 0.50, 0.80

s1 = rbox_center(ax, (xL, yb), (bw2, bh2), "1. Release particles every two months", wrap_width=26)
s2 = rbox_center(ax, (xC, yb), (bw2, bh2), "2. Identify particles that first arrive at coastal wetlands", wrap_width=26)
s3 = rbox_center(ax, (xR, yb), (bw2, bh2), "3. Sum total N and P for each coastal wetland", wrap_width=26)

# Diamond -> s1 as elbow (no diagonal crossing)
y_mid = 0.33
polyline(ax, [bottom(d), (0.5, y_mid), (xL, y_mid), top(s1)])

polyline(ax, [right(s1), left(s2)])
polyline(ax, [right(s2), left(s3)])

# Loop back
loop_y = 0.11
polyline(ax, [bottom(s3), (s3["cx"], loop_y)])
polyline(ax, [(s3["cx"], loop_y), (s1["cx"], loop_y)])
polyline(ax, [(s1["cx"], loop_y), bottom(s1)])
ax.text(0.5, loop_y - 0.035, "Repeat for 12 months",
        ha="center", va="center", fontsize=FONT, color="black")

# ----------------------------
# Export
# ----------------------------
png_path = "/home/abolmaal/modelling/FVCOM/Huron/Figures/flowchart_particle_tracking_6p69x5_fixed.png"
pdf_path = "/home/abolmaal/modelling/FVCOM/Huron/Figures/flowchart_particle_tracking_6p69x5_fixed.pdf"

plt.savefig(png_path, dpi=300, bbox_inches="tight")
with PdfPages(pdf_path) as pdf:
    pdf.savefig(fig, bbox_inches="tight")
plt.close(fig)

print("Saved:", png_path)
print("Saved:", pdf_path)
# Out:
# Saved: /home/abolmaal/modelling/FVCOM/Huron/Figures/flowchart_particle_tracking_6p69x5_fixed.png
# Saved: /home/abolmaal/modelling/FVCOM/Huron/Figures/flowchart_particle_tracking_6p69x5_fixed.pdf
