# %% [markdown]
# #

# %%
# import arcpy
import os
import pandas as pd
import geopandas as gpd
import arcpy.analysis

# %%
# Inputs
inDir = r"D:\Users\abolmaal\Arcgis\NASAOceanProject\GIS_layer"

inDir_shoreline = os.path.join(inDir, "shoreline","100K" ,"lh_shore_ESRI_100k_USside.shp")
