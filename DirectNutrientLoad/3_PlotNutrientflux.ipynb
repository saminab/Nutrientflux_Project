# %%
import pandas as pd
import numpy as np
#import arcpy
import os
import rasterio
from rasterio.warp import calculate_default_transform, reproject, Resampling
from rasterio.crs import CRS
import geopandas as gpd
# plot import 
import colorcet as cc
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from matplotlib_scalebar.scalebar import ScaleBar
import cmocean
import colormaps as cmaps 
import numpy as np, string, matplotlib as mpl

# %%
inDir = r"D:\Users\abolmaal\Arcgis\NASAOceanProject\Luwen_Nutrient"
#Huron_Lake = r"D:\Users\abolmaal\code\boundry\hydro_p_LakeHuron\hydro_p_LakeHuron.shp"
Huron_Lake = r"S:\Data\GIS_Data\Downloaded\Worldwide_Datasets\Natural_Earth_Data\10m_physical\ne_10m_lakes.shp"
Streamwatershed = r"D:\Users\abolmaal\Arcgis\NASAOceanProject\GIS_layer\Streamwatershed\PointWatershed_LH_NAD1983_NASA_Invasive.shp"
landshapefile  = r"S:\Data\GIS_Data\Downloaded\Worldwide_Datasets\Natural_Earth_Data\10m_cultural\ne_10m_admin_0_countries_lakes.shp"
inTN = os.path.join(inDir, "TN_Annual_delTotal_header_kgcellday.tif")
inTP = os.path.join(inDir, "TP_Annual_delTotal_header_kgcellday.tif")

# %%
import os
import string
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.patheffects as pe
from matplotlib_scalebar.scalebar import ScaleBar
import rasterio
import geopandas as gpd

# -----------------------------
# Map settings & units
# -----------------------------
CELL_SIZE_X = 119.986262
CELL_SIZE_Y = 119.977553
X_MIN, X_MAX = 0.89e6, 1.17e6
Y_MIN, Y_MAX = 0.65e6, 1.04e6

probs = [0.00, 0.25, 0.50, 0.75, 1.00]
font_size = 8
mpl.rcParams.update({
    'font.size': font_size,
    'font.family': 'sans-serif',
    'axes.linewidth': 0.6,
})

EXCLUDE_NONPOSITIVE = True
HIDE_NONPOSITIVE_ON_MAP = True

cell_area_ha = (CELL_SIZE_X * CELL_SIZE_Y) / 10_000.0
KG_CELL_DAY_to_KG_HA_YR = 365.0 / cell_area_ha

# -----------------------------
# Helpers
# -----------------------------
def add_panel_labels(axes, labels=None, dx=0.02, dy=0.98, fsize=None):
    axs = np.ravel(np.array(axes))
    if labels is None:
        labels = [f"{ch})" for ch in string.ascii_lowercase]
    if fsize is None:
        fsize = mpl.rcParams.get("font.size", 10) + 6
    for i, ax in enumerate(axs):
        lab = labels[i] if i < len(labels) else f"{string.ascii_lowercase[i]})"
        ax.text(dx, dy, lab, transform=ax.transAxes, ha="left", va="top",
                fontsize=fsize, fontweight="bold",
                bbox=dict(facecolor="white", edgecolor="none", alpha=0.7, pad=0.2),
                zorder=1000, clip_on=False)

def raster_extent(transform, h, w):
    left, top = transform.c, transform.f
    px_w, px_h = transform.a, transform.e
    return (left, left + w*px_w, top + h*px_h, top)

def to_kg_ha_yr(arr, nodata):
    a = arr.astype(float)
    if nodata is not None:
        a = np.where(arr == nodata, np.nan, a)
    return a * KG_CELL_DAY_to_KG_HA_YR

def quantile_breaks_positive(values, q_probs, exclude_nonpositive=True):
    v = values[np.isfinite(values)]
    if exclude_nonpositive:
        v = v[v > 0]
    if v.size == 0:
        raise ValueError("No positive finite values available to compute quantiles.")
    b = np.quantile(v, q_probs).astype(float)
    for i in range(1, len(b)):
        if b[i] <= b[i-1]:
            b[i] = np.nextafter(b[i-1], np.inf)
    return b

def boundary_norm(breaks):
    return mpl.colors.BoundaryNorm(breaks, ncolors=len(breaks)-1, clip=True)

def _fmt_val(v):
    if v == 0:
        return "0"
    mag = abs(v)
    if mag >= 1000:
        return f"{v:,.0f}"
    elif mag >= 10:
        return f"{v:.1f}"
    elif mag >= 1:
        return f"{v:.2f}"
    elif mag >= 0.1:
        return f"{v:.2f}"
    elif mag >= 0.01:
        return f"{v:.3f}"
    else:
        return f"{v:.4f}"

def smart_range_labels(breaks):
    """Open-ended bottom (< hi) and top (> lo); adaptive decimals in between."""
    b = np.asarray(breaks, float)
    n = len(b) - 1
    labels = []
    for i in range(n):
        lo, hi = b[i], b[i+1]
        if i == 0:
            labels.append(f"< {_fmt_val(hi)}")        # open-ended low end
        elif i == n - 1:
            labels.append(f"> {_fmt_val(lo)}")        # open-ended high end
        else:
            labels.append(f"{_fmt_val(lo)} – {_fmt_val(hi)}")
    return labels

def add_north_arrow(ax, x=0.93, y_tail=0.84, y_head=0.93, fsize=None):
    """North arrow, top-right, with white casing so it reads over the lake."""
    if fsize is None:
        fsize = font_size + 4
    ax.annotate(
        "", xy=(x, y_head), xytext=(x, y_tail),
        xycoords="axes fraction",
        arrowprops=dict(
            arrowstyle="-|>", color="black", lw=2.0, mutation_scale=14,
            path_effects=[pe.withStroke(linewidth=4.0, foreground="white")],
        ),
        annotation_clip=False, zorder=1001,
    )
    ax.text(
        x, y_head + 0.015, "N", transform=ax.transAxes,
        ha="center", va="bottom", fontsize=fsize, fontweight="bold",
        color="black", clip_on=False, zorder=1002,
        bbox=dict(facecolor="white", edgecolor="none", alpha=0.75, pad=0.5),
    )

def add_scale_bar(ax):
    map_width_m = X_MAX - X_MIN
    bar_m = round(map_width_m * 0.15, -4)
    scalebar = ScaleBar(
        dx=1, units="m", fixed_value=bar_m, fixed_units="m",
        length_fraction=None, location="lower left",
        pad=0.5, border_pad=0.8, sep=3, frameon=True, color="black",
        box_color="white", box_alpha=0.85,
        font_properties={"size": font_size + 2},
        label_formatter=lambda v, u: f"{int(v/1000)} km",
    )
    ax.add_artist(scalebar)

def plot_one(ax, arr_kg_ha_yr, transform, brks, lake_gdf, ws_gdf, land_gdf, title):
    data = arr_kg_ha_yr.copy()
    if HIDE_NONPOSITIVE_ON_MAP:
        data = np.where(np.isfinite(data) & (data <= 0), np.nan, data)

    h, w = data.shape
    extent = raster_extent(transform, h, w)

    # ── Journal-style colormap: 'matter' CAPPED at 0.88 so top isn't black ────
    # (keeps the watershed boundary visible against the high class)
    try:
        import cmocean
        cmap_disc = mpl.colors.ListedColormap(
            cmocean.cm.matter(np.linspace(0.05, 0.88, len(brks) - 1))
        )
    except ImportError:
        cmap_disc = mpl.colors.ListedColormap(
            plt.cm.YlOrRd(np.linspace(0.15, 0.92, len(brks) - 1))
        )

    norm = boundary_norm(brks)

    if land_gdf is not None and not land_gdf.empty:
        land_gdf.plot(ax=ax, facecolor="gainsboro", edgecolor="dimgray",
                      linewidth=0.4, zorder=0)

    im = ax.imshow(data, extent=extent, origin="upper",
                   cmap=cmap_disc, norm=norm, zorder=3)

    if lake_gdf is not None and not lake_gdf.empty:
        lake_gdf.plot(ax=ax, facecolor="lightsteelblue", edgecolor="#5b7aa6",
                      linewidth=0.3, zorder=6)

    # ── Watershed boundary with white casing (halo) so it pops everywhere ─────
    if ws_gdf is not None and not ws_gdf.empty:
        ws_gdf.boundary.plot(
            ax=ax, color="black", linewidth=0.9, zorder=8,
            path_effects=[pe.withStroke(linewidth=2.2, foreground="white")],
        )

    ax.set_aspect("equal")
    ax.set_xlim(X_MIN, X_MAX)
    ax.set_ylim(Y_MIN, Y_MAX)
    ax.set_xticks([]); ax.set_yticks([])
    ax.set_xlabel(""); ax.set_ylabel("")

    cbar = plt.colorbar(im, ax=ax, fraction=0.046, pad=0.02)
    mids = 0.5 * (np.array(brks[:-1]) + np.array(brks[1:]))
    cbar.set_ticks(mids)
    cbar.set_ticklabels(smart_range_labels(brks))
    cbar.ax.tick_params(labelsize=font_size + 2)
    cbar.outline.set_linewidth(0.6)
    cbar.ax.set_ylabel(r"kg ha$^{-1}$ yr$^{-1}$",
                       rotation=90, fontsize=font_size + 2, labelpad=6)

    add_north_arrow(ax)
    add_scale_bar(ax)

# -----------------------------
# Read rasters
# -----------------------------
with rasterio.open(inTN) as src_tn:
    arr_tn = src_tn.read(1); tr_tn = src_tn.transform
    crs_tn = src_tn.crs; nd_tn = src_tn.nodata
with rasterio.open(inTP) as src_tp:
    arr_tp = src_tp.read(1); tr_tp = src_tp.transform
    crs_tp = src_tp.crs; nd_tp = src_tp.nodata

tn_kg_ha_yr = to_kg_ha_yr(arr_tn, nd_tn)
tp_kg_ha_yr = to_kg_ha_yr(arr_tp, nd_tp)

# -----------------------------
# Vectors → raster CRS
# -----------------------------
lake = gpd.read_file(Huron_Lake).to_crs(crs_tn)
ws   = gpd.read_file(Streamwatershed).to_crs(crs_tn)
land = gpd.read_file(landshapefile).to_crs(crs_tn)

# -----------------------------
# Quantile breaks (positive only)
# -----------------------------
breaks_tn = quantile_breaks_positive(tn_kg_ha_yr, probs, exclude_nonpositive=EXCLUDE_NONPOSITIVE)
breaks_tp = quantile_breaks_positive(tp_kg_ha_yr, probs, exclude_nonpositive=EXCLUDE_NONPOSITIVE)

# -----------------------------
# Plot
# -----------------------------
dpi = 300
width_in  = 3508 / dpi
height_in = 2481 / dpi

fig, axes = plt.subplots(1, 2, figsize=(width_in, height_in), constrained_layout=True)
plot_one(axes[0], tn_kg_ha_yr, tr_tn, breaks_tn, lake, ws, land, "TN (Annual ΔTotal)")
plot_one(axes[1], tp_kg_ha_yr, tr_tp, breaks_tp, lake, ws, land, "TP (Annual ΔTotal)")
add_panel_labels(axes, labels=["a)", "b)"], dx=0.02, dy=0.98, fsize=font_size + 4)

Figure_path = r"S:\Users\Samin\Figures\chapter1\senseflux"
os.makedirs(Figure_path, exist_ok=True)
out_png = os.path.join(Figure_path, "TN_TP_quartiles_ws_outline.jpg")
fig.savefig(out_png, dpi=dpi, bbox_inches="tight")
print(f"Saved figure → {out_png}")
plt.close(fig)
# Out:
# Saved figure → S:\Users\Samin\Figures\chapter1\senseflux\TN_TP_quartiles_ws_outline.jpg

# %%
import colormaps as cmaps 
out_name    = "TN_TP_logbreaks_ws_outline_clean.jpg"
import matplotlib as mpl
import numpy as np
from matplotlib.colors import Colormap
# ============================================================
# STYLE / BEHAVIOR KNOBS
# ============================================================
font_size = 8
mpl.rcParams.update({'font.size': font_size})

# Map smoothing (DISPLAY ONLY)
COARSEN_FACTOR = 8          # 1 keeps original; 6-10 usually looks much cleaner

# Log-binning settings
N_LOG_BINS = 7              # 6–8 is usually good
Q_LO, Q_HI = 0.02, 0.98      # clip extremes before making log breaks

# Zero/negative handling
EXCLUDE_NONPOSITIVE = True
HIDE_NONPOSITIVE_ON_MAP = True

# Extent
EXTENT_PAD_M = 15000        # pad around watershed bounds

# Watershed outline style
DISSOLVE_WATERSHEDS = True  # cleaner than many internal boundaries

# Colormap choice (see note below)
CMAP_NAME   = 	cmaps.tropic    # good defaults: "cividis", "viridis", "magma"
CMAP_REVERSE = False
CMAP_TRIM   = (0.10, 0.95)  # avoid very pale/dark ends

# Tick label formatting
USE_SCI_FOR_TINY = True     # if False, tiny values become 0.00 with 2 decimals

# ============================================================
# HELPERS
# ============================================================
def add_panel_labels(axes, labels=None, dx=0.02, dy=0.98, fsize=None):
    axs = np.ravel(np.array(axes))
    if labels is None:
        labels = [f"{ch})" for ch in string.ascii_lowercase]
    if fsize is None:
        fsize = mpl.rcParams.get("font.size", 10) + 6
    for i, ax in enumerate(axs):
        lab = labels[i] if i < len(labels) else f"{string.ascii_lowercase[i]})"
        ax.text(dx, dy, lab, transform=ax.transAxes,
                ha="left", va="top", fontsize=fsize, fontweight="bold",
                bbox=dict(facecolor="none", edgecolor="none", pad=0.2),
                zorder=1000, clip_on=False)

def kg_cell_day_to_kg_ha_yr_factor(transform):
    px_w = abs(transform.a)
    px_h = abs(transform.e)
    cell_area_ha = (px_w * px_h) / 10_000.0
    return 365.0 / cell_area_ha

def to_kg_ha_yr(arr, nodata, transform):
    a = arr.astype(float)
    if nodata is not None:
        a = np.where(arr == nodata, np.nan, a)
    return a * kg_cell_day_to_kg_ha_yr_factor(transform)

def block_nanmean(a, f):
    if f is None or f == 1:
        return a
    h, w = a.shape
    h2 = (h // f) * f
    w2 = (w // f) * f
    a2 = a[:h2, :w2]
    a2 = a2.reshape(h2 // f, f, w2 // f, f)
    return np.nanmean(a2, axis=(1, 3))

def log_breaks(values, n_bins=7, q_lo=0.02, q_hi=0.98, exclude_nonpositive=True):
    v = values[np.isfinite(values)]
    if exclude_nonpositive:
        v = v[v > 0]
    if v.size == 0:
        raise ValueError("No positive finite values available for log breaks.")

    lo = float(np.quantile(v, q_lo))
    hi = float(np.quantile(v, q_hi))

    # safety
    lo = max(lo, np.nextafter(0, 1))
    if hi <= lo:
        hi = np.nextafter(lo, np.inf)

    b = np.geomspace(lo, hi, n_bins + 1)

    # ensure strictly increasing
    for i in range(1, len(b)):
        if b[i] <= b[i-1]:
            b[i] = np.nextafter(b[i-1], np.inf)
    return b

def boundary_norm(breaks):
    return mpl.colors.BoundaryNorm(breaks, ncolors=len(breaks)-1, clip=True)

def _fmt2(x):
    if not np.isfinite(x):
        return ""
    if (not USE_SCI_FOR_TINY) or (abs(x) >= 0.01):
        return f"{x:.2f}"
    return f"{x:.2e}"

def range_labels_2dec(breaks):
    b = np.asarray(breaks, float)
    return [f"{_fmt2(lo)}–{_fmt2(hi)}" for lo, hi in zip(b[:-1], b[1:])]

def auto_extent_from_gdf(gdf, pad=0):
    minx, miny, maxx, maxy = gdf.total_bounds
    return (minx - pad, maxx + pad, miny - pad, maxy + pad)

def sample_colors(n, cmap= "cividis", trim=(0.10, 0.95), reverse=False):
    """
    cmap can be:
      - a string (e.g., "cividis")
      - a matplotlib Colormap object (e.g., cmocean.cm.acton)
    """
    # resolve cmap
    if isinstance(cmap, str):
        cmap_obj = mpl.colormaps[cmap] if hasattr(mpl, "colormaps") else mpl.cm.get_cmap(cmap)
    elif isinstance(cmap, Colormap):
        cmap_obj = cmap
    else:
        # also allow callables that behave like colormaps
        cmap_obj = cmap

    t = np.linspace(trim[0], trim[1], n)
    cols = cmap_obj(t)
    if reverse:
        cols = cols[::-1]
    return cols

def plot_one(ax, cax, data_kg_ha_yr, transform, brks,
             lake_gdf, ws_outline_gdf, land_gdf,
             xlim, ylim):

    # hide nonpositive
    data = data_kg_ha_yr.copy()
    if HIDE_NONPOSITIVE_ON_MAP:
        data = np.where(np.isfinite(data) & (data <= 0), np.nan, data)

    # coarsen for display
    data_plot = block_nanmean(data, COARSEN_FACTOR)
    tr_plot = transform * Affine.scale(COARSEN_FACTOR, COARSEN_FACTOR)

    h, w = data_plot.shape
    west, south, east, north = array_bounds(h, w, tr_plot)
    extent = (west, east, south, north)

    # discrete cmap
    n_bins = len(brks) - 1
    colors = sample_colors(n_bins, CMAP_NAME, trim=CMAP_TRIM, reverse=CMAP_REVERSE)
    cmap_disc = mpl.colors.ListedColormap(colors)
    norm = boundary_norm(brks)

    # land underlay
    if land_gdf is not None and not land_gdf.empty:
        land_gdf.plot(ax=ax, facecolor="0.90", edgecolor="0.55", linewidth=0.35, zorder=0)

    # raster
    im = ax.imshow(
        data_plot, extent=extent, origin="upper",
        cmap=cmap_disc, norm=norm,
        interpolation="nearest", zorder=3
    )

    # mask lake over raster
    if lake_gdf is not None and not lake_gdf.empty:
        lake_gdf.plot(ax=ax, facecolor="white", edgecolor="#5b7aa6", linewidth=0.35, zorder=6)

    # watershed outline
    if ws_outline_gdf is not None and not ws_outline_gdf.empty:
        ws_outline_gdf.plot(ax=ax, color="black", linewidth=0.55, zorder=8)

    # axes
    ax.set_aspect("equal")
    ax.set_xlim(*xlim)
    ax.set_ylim(*ylim)
    ax.set_xticks([]); ax.set_yticks([])
    for sp in ax.spines.values():
        sp.set_linewidth(0.8)

    # colorbar (log bins -> geometric midpoints)
    cbar = plt.colorbar(im, cax=cax)
    mids = np.sqrt(np.array(brks[:-1]) * np.array(brks[1:]))
    cbar.set_ticks(mids)
    cbar.set_ticklabels(range_labels_2dec(brks))
    cbar.ax.tick_params(labelsize=font_size + 1)
    cbar.set_label(r"kg ha$^{-1}$ yr$^{-1}$", fontsize=font_size + 2)

# ============================================================
# READ RASTERS
# ============================================================
for lab, fp in [("TN", inTN), ("TP", inTP)]:
    if not os.path.exists(fp):
        raise FileNotFoundError(f"{lab} raster not found:\n  {fp}")

with rasterio.open(inTN) as src_tn:
    arr_tn = src_tn.read(1)
    tr_tn  = src_tn.transform
    crs_tn = src_tn.crs
    nd_tn  = src_tn.nodata

with rasterio.open(inTP) as src_tp:
    arr_tp = src_tp.read(1)
    tr_tp  = src_tp.transform
    crs_tp = src_tp.crs
    nd_tp  = src_tp.nodata

tn_kg_ha_yr = to_kg_ha_yr(arr_tn, nd_tn, tr_tn)
tp_kg_ha_yr = to_kg_ha_yr(arr_tp, nd_tp, tr_tp)

# ============================================================
# VECTORS → raster CRS
# ============================================================
lake = gpd.read_file(Huron_Lake).to_crs(crs_tn)
ws   = gpd.read_file(Streamwatershed).to_crs(crs_tn)
land = gpd.read_file(landshapefile).to_crs(crs_tn)

# dissolve to a single outline
if DISSOLVE_WATERSHEDS:
    ws_d = ws.dissolve()
    ws_outline = gpd.GeoDataFrame(geometry=ws_d.boundary, crs=ws.crs)
else:
    ws_outline = gpd.GeoDataFrame(geometry=ws.boundary, crs=ws.crs)

# extent from watershed bounds
xmin, xmax, ymin, ymax = auto_extent_from_gdf(ws, pad=EXTENT_PAD_M)
xlim = (xmin, xmax)
ylim = (ymin, ymax)

# ============================================================
# LOG BREAKS (compute on what you SEE: coarsened)
# ============================================================
tn_for_breaks = block_nanmean(tn_kg_ha_yr, COARSEN_FACTOR)
tp_for_breaks = block_nanmean(tp_kg_ha_yr, COARSEN_FACTOR)

breaks_tn = log_breaks(tn_for_breaks, n_bins=N_LOG_BINS, q_lo=Q_LO, q_hi=Q_HI,
                      exclude_nonpositive=EXCLUDE_NONPOSITIVE)
breaks_tp = log_breaks(tp_for_breaks, n_bins=N_LOG_BINS, q_lo=Q_LO, q_hi=Q_HI,
                      exclude_nonpositive=EXCLUDE_NONPOSITIVE)

# If you want SHARED breaks across TN+TP, uncomment:
# all_for_breaks = np.concatenate([tn_for_breaks.ravel(), tp_for_breaks.ravel()])
# breaks_shared = log_breaks(all_for_breaks, n_bins=N_LOG_BINS, q_lo=Q_LO, q_hi=Q_HI,
#                            exclude_nonpositive=EXCLUDE_NONPOSITIVE)
# breaks_tn = breaks_tp = breaks_shared

# ============================================================
# PLOT (dedicated cbar axes -> easy to "move" them)
# ============================================================
dpi = 300
fig = plt.figure(figsize=(11.0, 4.6), dpi=dpi)
gs = fig.add_gridspec(1, 4, width_ratios=[1, 0.045, 1, 0.045], wspace=0.009)

ax1  = fig.add_subplot(gs[0, 0])
cax1 = fig.add_subplot(gs[0, 1])   # left colorbar (between)
ax2  = fig.add_subplot(gs[0, 2])
cax2 = fig.add_subplot(gs[0, 3])   # right colorbar (far right)

# shift colorbars left by a small amount (figure fraction)
dx = 0.07 # try 0.005–0.02

pos = cax1.get_position()
cax1.set_position([pos.x0 - dx, pos.y0, pos.width, pos.height])

pos = cax2.get_position()
cax2.set_position([pos.x0 - dx, pos.y0, pos.width, pos.height])

plot_one(ax1, cax1, tn_kg_ha_yr, tr_tn, breaks_tn, lake, ws_outline, land, xlim, ylim)
plot_one(ax2, cax2, tp_kg_ha_yr, tr_tp, breaks_tp, lake, ws_outline, land, xlim, ylim)

add_panel_labels([ax1, ax2], labels=["a)", "b)"], dx=0.02, dy=0.98, fsize=font_size + 4)

# save
os.makedirs(Figure_path, exist_ok=True)
out_png = os.path.join(Figure_path, out_name)
fig.savefig(out_png, dpi=dpi, bbox_inches="tight")
plt.close(fig)
print(f"Saved figure → {out_png}")
# Out:
# C:\Users\abolmaal\AppData\Local\Temp\ipykernel_42524\3515657559.py:73: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a2, axis=(1, 3))
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 274
#     271 pos = cax2.get_position()
#     272 cax2.set_position([pos.x0 - dx, pos.y0, pos.width, pos.height])
# --> 274 plot_one(ax1, cax1, tn_kg_ha_yr, tr_tn, breaks_tn, lake, ws_outline, land, xlim, ylim)
#     275 plot_one(ax2, cax2, tp_kg_ha_yr, tr_tp, breaks_tp, lake, ws_outline, land, xlim, ylim)
#     277 add_panel_labels([ax1, ax2], labels=["a)", "b)"], dx=0.02, dy=0.98, fsize=font_size + 4)
#
# Cell In[7], line 148, in plot_one(ax, cax, data_kg_ha_yr, transform, brks, lake_gdf, ws_outline_gdf, land_gdf, xlim, ylim)
#     146 # coarsen for display
#     147 data_plot = block_nanmean(data, COARSEN_FACTOR)
# ...
